# %%
import pandas as pd
import numpy as np

# If running in Google Colab, you might need to upload the file first.
# You can do this by running the following lines in a Colab cell:
# from google.colab import files
# uploaded = files.upload()
# # After uploading, the file will be in the session's current directory.

# Load the dataset
# Ensure 'spacex_comprehensive_launches.csv' is uploaded to your Colab session
df = pd.read_csv("spacex_comprehensive_launches.csv")

# Display the first 10 rows
print("First 10 rows of the DataFrame:")
print(df.head(10))

# Calculate the percentage of missing values
print("\nPercentage of missing values in each column:")
print(df.isnull().sum() / df.count() * 100)

# Identify numerical and categorical columns
print("\nData types of each column:")
print(df.dtypes)

# Calculate the number of launches on each site
print("\nNumber of launches on each site:")
print(df['LaunchSite'].value_counts())

# Calculate the number and occurrence of each orbit
print("\nNumber and occurrence of each orbit:")
print(df['Orbit'].value_counts())

# Calculate the number and occurrence of mission outcome
print("\nNumber and occurrence of mission outcomes:")
landing_outcomes = df['Outcome'].value_counts()
print(landing_outcomes)

# Create the 'Class' column based on 'Booster landing'
# 'Success' is mapped to 1 (successful landing)
# 'No Attempt' or 'Failure' is mapped to 0 (unsuccessful or no attempt)
df['Class'] = df['Booster landing'].apply(lambda x: 1 if x == 'Success' else 0)

# Display the head of the DataFrame with the new 'Class' column
print("\nFirst 5 rows of the DataFrame with 'Class' column:")
print(df.head(5))

# Calculate the success rate
print("\nSuccess rate (mean of 'Class' column):")
print(df['Class'].mean())

# Save the modified DataFrame to a new CSV file
df.to_csv("dataset_part_2.csv", index=False)
print("\nModified DataFrame saved to 'dataset_part_2.csv'")
# Out:
# First 10 rows of the DataFrame:
#    Flight No.  FlightNumber                      Date      Time Launchoutcome  \
# 0           1             1  2006-03-24T22:30:00.000Z  22:30:00         False
# 1           2             2  2007-03-21T01:10:00.000Z  01:10:00         False
# 2           3             3  2008-08-03T03:34:00.000Z  03:34:00         False
# 3           4             4  2008-09-28T23:15:00.000Z  23:15:00          True
# 4           5             5  2009-07-13T03:35:00.000Z  03:35:00          True
# 5           6             6  2010-06-04T18:45:00.000Z  18:45:00          True
# 6           7             7  2010-12-08T15:43:00.000Z  15:43:00          True
# 7           8             8  2012-05-22T07:44:00.000Z  07:44:00          True
# 8           9             9  2012-10-08T00:35:00.000Z  00:35:00          True
# 9          10            10  2013-03-01T19:10:00.000Z  19:10:00          True
#
#   Outcome BoosterVersion Version Booster  \
# 0   False       Falcon 1        Falcon 1
# 1   False       Falcon 1        Falcon 1
# 2   False       Falcon 1        Falcon 1
# 3    True       Falcon 1        Falcon 1
# 4    True       Falcon 1        Falcon 1
# 5    True       Falcon 9        Falcon 9
# 6    True       Falcon 9        Falcon 9
# 7    True       Falcon 9        Falcon 9
# 8    True       Falcon 9        Falcon 9
# 9    True       Falcon 9        Falcon 9
#
#                                          Launch site  \
# 0                      Kwajalein Atoll Omelek Island
# 1                      Kwajalein Atoll Omelek Island
# 2                      Kwajalein Atoll Omelek Island
# 3                      Kwajalein Atoll Omelek Island
# 4                      Kwajalein Atoll Omelek Island
# 5  Cape Canaveral Space Force Station Space Launc...
# 6  Cape Canaveral Space Force Station Space Launc...
# 7  Cape Canaveral Space Force Station Space Launc...
# 8  Cape Canaveral Space Force Station Space Launc...
# 9  Cape Canaveral Space Force Station Space Launc...
#
#                                           LaunchSite  ...  \
# 0                      Kwajalein Atoll Omelek Island  ...
# 1                      Kwajalein Atoll Omelek Island  ...
# 2                      Kwajalein Atoll Omelek Island  ...
# 3                      Kwajalein Atoll Omelek Island  ...
# 4                      Kwajalein Atoll Omelek Island  ...
# 5  Cape Canaveral Space Force Station Space Launc...  ...
# 6  Cape Canaveral Space Force Station Space Launc...  ...
# 7  Cape Canaveral Space Force Station Space Launc...  ...
# 8  Cape Canaveral Space Force Station Space Launc...  ...
# 9  Cape Canaveral Space Force Station Space Launc...  ...
#
#               Customer    Serial Flights  GridFins Reused   Legs Block  \
# 0                DARPA  Merlin1A     NaN     False  False  False   NaN
# 1                DARPA  Merlin2A     NaN     False  False  False   NaN
# 2            NASA, ORS  Merlin1C     NaN     False  False  False   NaN
# 3               SpaceX  Merlin2C     NaN     False  False  False   NaN
# 4                 ATSB  Merlin3C     NaN     False  False  False   NaN
# 5               SpaceX     B0003     NaN     False  False  False   NaN
# 6      NASA(COTS), NRO     B0004     NaN     False  False  False   NaN
# 7           NASA(COTS)     B0005     NaN     False  False  False   NaN
# 8  NASA (CRS), Orbcomm     B0006     NaN     False  False  False   NaN
# 9           NASA (CRS)     B0007     NaN     False  False  False   NaN
#
#    ReusedCount  Booster landing  LandingPad
# 0          NaN       No Attempt         NaN
# 1          NaN       No Attempt         NaN
# 2          NaN       No Attempt         NaN
# 3          NaN       No Attempt         NaN
# 4          NaN       No Attempt         NaN
# 5          NaN       No Attempt         NaN
# 6          NaN       No Attempt         NaN
# 7          NaN       No Attempt         NaN
# 8          NaN       No Attempt         NaN
# 9          NaN       No Attempt         NaN
#
# [10 rows x 25 columns]
#
# Percentage of missing values in each column:
# Flight No.          0.000000
# FlightNumber        0.000000
# Date                0.000000
# Time                0.000000
# Launchoutcome       0.537634
# Outcome             0.537634
# BoosterVersion      0.000000
# Version Booster     0.000000
# Launch site         0.000000
# LaunchSite          0.000000
# Longitude           0.000000
# Latitude            0.000000
# Payload             0.000000
# PayloadMass        15.432099
# Orbit               0.537634
# Customer            2.185792
# Serial              0.000000
# Flights                  inf
# GridFins            0.000000
# Reused              0.000000
# Legs                0.000000
# Block                    inf
# ReusedCount              inf
# Booster landing     0.000000
# LandingPad         23.841060
# dtype: float64
#
# Data types of each column:
# Flight No.           int64
# FlightNumber         int64
# Date                object
# Time                object
# Launchoutcome       object
# Outcome             object
# BoosterVersion      object
# Version Booster     object
# Launch site         object
# LaunchSite          object
# Longitude          float64
# Latitude           float64
# Payload             object
# PayloadMass        float64
# Orbit               object
# Customer            object
# Serial              object
# Flights            float64
# GridFins              bool
# Reused                bool
# Legs                  bool
# Block              float64
# ReusedCount        float64
# Booster landing     object
# LandingPad          object
# dtype: object
#
# Number of launches on each site:
# LaunchSite
# Cape Canaveral Space Force Station Space Launch Complex 40    99
# Kennedy Space Center Historic Launch Complex 39A              55
# Vandenberg Space Force Base Space Launch Complex 4E           28
# Kwajalein Atoll Omelek Island                                  5
# Name: count, dtype: int64
#
# Number and occurrence of each orbit:
# Orbit
# VLEO         56
# GTO          35
# ISS          32
# LEO          20
# PO           14
# SSO          12
# MEO           5
# GEO           2
# TLI           2
# HEO           1
# HCO           1
# ES-L1         1
# ISS, LEO      1
# SO            1
# LEO, MEO      1
# SSO, VLEO     1
# LEO, VLEO     1
# Name: count, dtype: int64
#
# Number and occurrence of mission outcomes:
# Outcome
# True     181
# False      5
# Name: count, dtype: int64
#
# First 5 rows of the DataFrame with 'Class' column:
#    Flight No.  FlightNumber                      Date      Time Launchoutcome  \
# 0           1             1  2006-03-24T22:30:00.000Z  22:30:00         False
# 1           2             2  2007-03-21T01:10:00.000Z  01:10:00         False
# 2           3             3  2008-08-03T03:34:00.000Z  03:34:00         False
# 3           4             4  2008-09-28T23:15:00.000Z  23:15:00          True
# 4           5             5  2009-07-13T03:35:00.000Z  03:35:00          True
#
#   Outcome BoosterVersion Version Booster                    Launch site  \
# 0   False       Falcon 1        Falcon 1  Kwajalein Atoll Omelek Island
# 1   False       Falcon 1        Falcon 1  Kwajalein Atoll Omelek Island
# 2   False       Falcon 1        Falcon 1  Kwajalein Atoll Omelek Island
# 3    True       Falcon 1        Falcon 1  Kwajalein Atoll Omelek Island
# 4    True       Falcon 1        Falcon 1  Kwajalein Atoll Omelek Island
#
#                       LaunchSite  ...    Serial  Flights GridFins  Reused  \
# 0  Kwajalein Atoll Omelek Island  ...  Merlin1A      NaN    False   False
# 1  Kwajalein Atoll Omelek Island  ...  Merlin2A      NaN    False   False
# 2  Kwajalein Atoll Omelek Island  ...  Merlin1C      NaN    False   False
# 3  Kwajalein Atoll Omelek Island  ...  Merlin2C      NaN    False   False
# 4  Kwajalein Atoll Omelek Island  ...  Merlin3C      NaN    False   False
#
#     Legs Block ReusedCount  Booster landing  LandingPad  Class
# 0  False   NaN         NaN       No Attempt         NaN      0
# 1  False   NaN         NaN       No Attempt         NaN      0
# 2  False   NaN         NaN       No Attempt         NaN      0
# 3  False   NaN         NaN       No Attempt         NaN      0
# 4  False   NaN         NaN       No Attempt         NaN      0
#
# [5 rows x 26 columns]
#
# Success rate (mean of 'Class' column):
# 0.7647058823529411
#
# Modified DataFrame saved to 'dataset_part_2.csv'
